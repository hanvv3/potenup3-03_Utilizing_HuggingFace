# %%
import pandas as pd

# %% [markdown]
# # 1. 데이터 불러오기

# %%
df = pd.read_csv('./hand_data.csv', header=None)
df.head()
# Out:
#          0         1             2         3         4         5         6   \
# 0  0.708618  0.726508  4.931828e-07  0.651716  0.728453 -0.023138  0.596217
# 1  0.704302  0.726838  4.915186e-07  0.648160  0.728611 -0.022461  0.592547
# 2  0.684500  0.742820  5.485762e-07  0.627028  0.733941 -0.024318  0.576412
# 3  0.663071  0.734723  5.286115e-07  0.603253  0.728509 -0.020485  0.553365
# 4  0.676052  0.722018  4.886666e-07  0.618586  0.726268 -0.018217  0.561764
#
#          7         8         9   ...        54        55        56        57  \
# 0  0.684290 -0.037493  0.581995  ...  0.662557  0.480840 -0.072301  0.656634
# 1  0.685299 -0.036726  0.577028  ...  0.659084  0.484208 -0.072856  0.652843
# 2  0.682249 -0.040027  0.571010  ...  0.669921  0.495559 -0.077260  0.661319
# 3  0.680227 -0.034699  0.532234  ...  0.611850  0.502989 -0.072672  0.598922
# 4  0.690471 -0.031905  0.537742  ...  0.600835  0.496626 -0.070187  0.594168
#
# ...

# %%
# 컬럼 이름 바꾸기
# 열 개수: 64 (=21 개 * 3(XYZ) + 1 label)
columns = []
for i in range(21):
    columns.extend([f'x{i+1}', f'y{i+1}', f'z{i+1}'])
columns.append('label')

print(len(columns))
print(columns)
# Out:
# 64
# ['x1', 'y1', 'z1', 'x2', 'y2', 'z2', 'x3', 'y3', 'z3', 'x4', 'y4', 'z4', 'x5', 'y5', 'z5', 'x6', 'y6', 'z6', 'x7', 'y7', 'z7', 'x8', 'y8', 'z8', 'x9', 'y9', 'z9', 'x10', 'y10', 'z10', 'x11', 'y11', 'z11', 'x12', 'y12', 'z12', 'x13', 'y13', 'z13', 'x14', 'y14', 'z14', 'x15', 'y15', 'z15', 'x16', 'y16', 'z16', 'x17', 'y17', 'z17', 'x18', 'y18', 'z18', 'x19', 'y19', 'z19', 'x20', 'y20', 'z20', 'x21', 'y21', 'z21', 'label']

# %% [markdown]
# # 2. 데이터 분할하기

# %% [markdown]
# # 3. 모델 학습

# %% [markdown]
# # 4. 모델 성능 평가

# %% [markdown]
# # 5. 모델 내보내기
