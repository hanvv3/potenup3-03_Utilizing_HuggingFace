# %% [markdown]
# # 실습 1. 주민등록증 비식별화 하기 (EasyOCR)

# %%
# 라이브러리 설치: uv add easyocr
import easyocr
import matplotlib.pyplot as plt
from PIL import Image

# %%
# 이슈 해결 
## 이슈 1: AttributeError: 'NoneType' object has no attribute 'shape'
### 이미지 경로 영어로 바꾸기
### mac, linux에서는 한글로 해도 됨

## 이슈 2: AttributeError: module 'cv2' has no attribute '__version__'
### 해결 방안: 깃허브로 설치 
### uv remove easyocr 
### uv add "easyocr @ git+https://github.com/JaidedAI/EasyOCR.git"

# %% [markdown]
# ## 1. 이미지 불러오기

# %%
import matplotlib.pyplot as plt
from PIL import Image

image_path = './images/id_card_sample.jpg'
image = Image.open(image_path)

plt.imshow(image)
plt.axis('off')
plt.show()

# %% [markdown]
# ## 2. OCR로 텍스트 추출

# %%
reader = easyocr.Reader(['ko', 'en'])

# %%
# PIL 은 RGB, cv2는 BGR이기 때문에 결과가 달라졌었다... image_path로 불러오는 것이 중요하다.
results = reader.readtext(image_path)
results
# Out:
# [([[np.int32(37), np.int32(10)],
#    [np.int32(140), np.int32(10)],
#    [np.int32(140), np.int32(41)],
#    [np.int32(37), np.int32(41)]],
#   '주민등록증',
#   np.float64(0.9948592663649652)),
#  ([[np.int32(35), np.int32(43)],
#    [np.int32(131), np.int32(43)],
#    [np.int32(131), np.int32(63)],
#    [np.int32(35), np.int32(63)]],
#   '흥기동 (슴 표)',
#   np.float64(0.054392333824688714)),
#  ([[np.int32(29), np.int32(67)],
#    [np.int32(79), np.int32(67)],
#    [np.int32(79), np.int32(81)],
#    [np.int32(29), np.int32(81)]],
#   '501111',
#   np.float64(0.8646842497707816)),
#  ([[np.int32(83), np.int32(67)],
#    [np.int32(139), np.int32(67)],
#    [np.int32(139), np.int32(81)],
#    [np.int32(83), np.int32(81)]],
#   '1234566',
#   np.float64(0.49360216031985577)),
#  ([[np.int32(21), np.int32(83)],
#    [np.int32(153), np.int32(83)],
#    [np.int32(153), np.int32(123)],
#    [np.int32(21), np.int32(123)]],
#   '#  {93-33',
#   np.float64(0.006661895701082788)),
#  ([[np.int32(65), np.int32(107)],
#    [np.int32(115), np.int32(107)],
#    [np.int32(115), np.int32(121)],
#    [np.int32(65), np.int32(121)]],
#   '집달여하다',
#   np.float64(0.13090858697960656)),
#  ([[np.int32(101), np.int32(129)],
#    [np.int32(129), np.int32(129)],
#    [np.int32(129), np.int32(141)],
#    [np.int32(101), np.int32(141)]],
#   '309',
#   np.float64(0.763899337094333)),
#  ([[np.int32(69), np.int32(141)],
#    [np.int32(189), np.int32(141)],
#    [np.int32(189), np.int32(157)],
#    [np.int32(69), np.int32(157)]],
#   '서용들명시 중로구성장',
#   np.float64(0.15027595116353124))]

# %% [markdown]
# ### 이미지에 박스 그리기

# %%
from PIL import ImageDraw

image_boxes = image.copy()
draw = ImageDraw.Draw(image_boxes)

for bbox, text, score in results:
    x1 = int(bbox[0][0])
    y1 = int(bbox[0][1])
    x2 = int(bbox[2][0])
    y2 = int(bbox[2][1])
    draw.rectangle([x1, y1, x2, y2], outline="red", width=2)

plt.figure(figsize=(6, 4))
plt.imshow(image_boxes)
plt.axis("off")
plt.show()

# %% [markdown]
# ## 3. 주민등록번호 뒷자리 검은색 박스로 채우기

# %%
results[3]
# Out:
# ([[np.int32(83), np.int32(67)],
#   [np.int32(139), np.int32(67)],
#   [np.int32(139), np.int32(81)],
#   [np.int32(83), np.int32(81)]],
#  '1234566',
#  np.float64(0.49360216031985577))

# %%
image_masked = image.copy()
draw = ImageDraw.Draw(image_masked)

bbox, text, score = results[3]
# 주민번호 패턴 감지: 앞 6자리 - 뒤 7자리
x1 = int(bbox[0][0])
y1 = int(bbox[0][1])
x2 = int(bbox[2][0])
y2 = int(bbox[2][1])

draw.rectangle([x1, y1, x2, y2], fill="black")

plt.figure(figsize=(6, 4))
plt.imshow(image_masked)
plt.axis("off")
plt.title("Result")
plt.show()

# %% [markdown]
# # 실습 2: 만화 번역하기 (Google Vision Cloud)

# %%
# 라이브러리 설치 uv add google-cloud-vision
from google.cloud import vision
import os
import matplotlib.pyplot as plt 
from PIL import Image 

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "./google_vision_api.json"
# ./google_vision_api.json을 깃허브에 절대 올리지 말 것(.gitignore 추가)

# %%
client = vision.ImageAnnotatorClient()

# %%
image_path = "./images/webtoon.jpeg"

image = Image.open(image_path)

plt.imshow(image)
plt.axis("off")
plt.show()

# %%
with open(image_path, "rb") as f:
    content = f.read()

vision_image = vision.Image(content=content)
response = client.text_detection(image=vision_image)

response
# Out:
# text_annotations {
#   locale: "ko"
#   description: "\"어제 이거 가지고 노는 것도\n너무 귀여웠지\n그러게~ 언제 이렇게 컸지?\nTOOK"
#   bounding_poly {
#     vertices {
#       x: 49
#       y: 43
#     }
#     vertices {
#       x: 662
#       y: 43
#     }
#     vertices {
#       x: 662
#       y: 702
#     }
#     vertices {
#       x: 49
#       y: 702
#     }
#   }
# }
# text_annotations {
#   description: "\""
#   bounding_poly {
#     vertices {
#       x: 49
#       y: 43
#     }
#     vertices {
#       x: 65
#       y: 43
#     }
#     vertices {
#       x: 65
#       y: 76
#     }
#     vertices {
#       x: 49
#       y: 76
#     }
#   }
# }
# text_annotations {
#   description: "어제"
#   bounding_poly {
#     vertices {
#       x: 58
#       y: 43
#     }
#     vertices {
#       x: 116
#       y: 43
#     }
#     vertices {
#       x: 116
#       y: 76
#     }
#     vertices {
#       x: 58
#       y: 76
#     }
#   }
# }
# text_annotations {
#   description: "이거"
#   bounding_poly {
#     vertices {
#       x: 131
#       y: 43
#     }
#     vertices {
#       x: 187
#       y: 43
#     }
#     vertices {
#       x: 187
#       y: 76
#     }
#     vertices {
#       x: 131
#       y: 76
#     }
#   }
# }
# text_annotations {
#   description: "가지고"
#   bounding_poly {
#     vertices {
#       x: 203
#       y: 43
#     }
#     vertices {
#       x: 294
#       y: 43
#     }
#     vertices {
#       x: 294
#       y: 76
#     }
#     vertices {
#       x: 203
#       y: 76
#     }
#   }
# }
# text_annotations {
#   description: "노는"
#   bounding_poly {
#     vertices {
#       x: 305
#       y: 43
#     }
#     vertices {
#       x: 366
#       y: 43
#     }
#     vertices {
#       x: 366
#       y: 76
#     }
#     vertices {
#       x: 305
#       y: 76
#     }
#   }
# }
# text_annotations {
#   description: "것도"
#   bounding_poly {
#     vertices {
#       x: 377
#       y: 43
#     }
#     vertices {
#       x: 438
#       y: 43
#     }
#     vertices {
#       x: 438
#       y: 76
#     }
#     vertices {
#       x: 377
#       y: 76
#     }
#   }
# }
# text_annotations {
#   description: "너무"
#   bounding_poly {
#     vertices {
#       x: 151
#       y: 85
#     }
#     vertices {
#       x: 211
#       y: 85
#     }
#     vertices {
#       x: 211
#       y: 117
#     }
#     vertices {
#       x: 151
#       y: 117
#     }
#   }
# }
# text_annotations {
#   description: "귀여웠"
#   bounding_poly {
#     vertices {
#       x: 221
#       y: 85
#     }
#     vertices {
#       x: 315
#       y: 85
#     }
#     vertices {
#       x: 315
#       y: 117
#     }
#     vertices {
#       x: 221
#       y: 117
#     }
#   }
# }
# text_annotations {
#   description: "지"
#   bounding_poly {
#     vertices {
#       x: 315
#       y: 85
#     }
#     vertices {
#       x: 342
#       y: 85
#     }
#     vertices {
#       x: 342
#       y: 117
#     }
#     vertices {
#       x: 315
#       y: 117
#     }
#   }
# }
# text_annotations {
#   description: "그러게"
#   bounding_poly {
#     vertices {
#       x: 266
#       y: 651
#     }
#     vertices {
#       x: 356
#       y: 651
#     }
#     vertices {
#       x: 356
#       y: 683
#     }
#     vertices {
#       x: 266
#       y: 683
#     }
#   }
# }
# text_annotations {
#   description: "~"
#   bounding_poly {
#     vertices {
#       x: 362
#       y: 651
#     }
#     vertices {
#       x: 378
#       y: 651
#     }
#     vertices {
#       x: 378
#       y: 683
#     }
#     vertices {
#       x: 362
#       y: 683
#     }
#   }
# }
# text_annotations {
#   description: "언제"
#   bounding_poly {
#     vertices {
#       x: 393
#       y: 651
#     }
#     vertices {
#       x: 449
#       y: 651
#     }
#     vertices {
#       x: 449
#       y: 683
#     }
#     vertices {
#       x: 393
#       y: 683
#     }
#   }
# }
# text_annotations {
#   description: "이렇게"
#   bounding_poly {
#     vertices {
#       x: 465
#       y: 651
#     }
#     vertices {
#       x: 553
#       y: 651
#     }
#     vertices {
#       x: 553
#       y: 683
#     }
#     vertices {
#       x: 465
#       y: 683
#     }
#   }
# }
# text_annotations {
#   description: "컸지"
#   bounding_poly {
#     vertices {
#       x: 570
#       y: 651
#     }
#     vertices {
#       x: 625
#       y: 651
#     }
#     vertices {
#       x: 625
#       y: 683
#     }
#     vertices {
#       x: 570
#       y: 683
#     }
#   }
# }
# text_annotations {
#   description: "?"
#   bounding_poly {
#     vertices {
#       x: 630
#       y: 651
#     }
#     vertices {
#       x: 644
#       y: 651
#     }
#     vertices {
#       x: 644
#       y: 683
#     }
#     vertices {
#       x: 630
#       y: 683
#     }
#   }
# }
# text_annotations {
#   description: "TOOK"
#   bounding_poly {
#     vertices {
#       x: 598
#       y: 683
#     }
#     vertices {
#       x: 661
#       y: 681
#     }
#     vertices {
#       x: 662
#       y: 700
#     }
#     vertices {
#       x: 599
#       y: 702
#     }
#   }
# }
# full_text_annotation {
#   pages {
#     property {
#       detected_languages {
#         language_code: "ko"
#         confidence: 0.910294056
#       }
#     }
#     width: 690
#     height: 750
#     blocks {
#       bounding_box {
#         vertices {
#           x: 49
#           y: 43
#         }
#         vertices {
#           x: 438
#           y: 43
#         }
#         vertices {
#           x: 438
#           y: 76
#         }
#         vertices {
#           x: 49
#           y: 76
#         }
#       }
#       paragraphs {
#         bounding_box {
#           vertices {
#             x: 49
#             y: 43
#           }
#           vertices {
#             x: 438
#             y: 43
#           }
#           vertices {
#             x: 438
#             y: 76
#           }
#           vertices {
#             x: 49
#             y: 76
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "ko"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 49
#               y: 43
#             }
#             vertices {
#               x: 65
#               y: 43
#             }
#             vertices {
#               x: 65
#               y: 76
#             }
#             vertices {
#               x: 49
#               y: 76
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 49
#                 y: 43
#               }
#               vertices {
#                 x: 65
#                 y: 43
#               }
#               vertices {
#                 x: 65
#                 y: 76
#               }
#               vertices {
#                 x: 49
#                 y: 76
#               }
#             }
#             text: "\""
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "ko"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 58
#               y: 43
#             }
#             vertices {
#               x: 116
#               y: 43
#             }
#             vertices {
#               x: 116
#               y: 76
#             }
#             vertices {
#               x: 58
#               y: 76
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 58
#                 y: 43
#               }
#               vertices {
#                 x: 83
#                 y: 43
#               }
#               vertices {
#                 x: 83
#                 y: 76
#               }
#               vertices {
#                 x: 58
#                 y: 76
#               }
#             }
#             text: "어"
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 88
#                 y: 43
#               }
#               vertices {
#                 x: 116
#                 y: 43
#               }
#               vertices {
#                 x: 116
#                 y: 76
#               }
#               vertices {
#                 x: 88
#                 y: 76
#               }
#             }
#             text: "제"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "ko"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 131
#               y: 43
#             }
#             vertices {
#               x: 187
#               y: 43
#             }
#             vertices {
#               x: 187
#               y: 76
#             }
#             vertices {
#               x: 131
#               y: 76
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 131
#                 y: 43
#               }
#               vertices {
#                 x: 156
#                 y: 43
#               }
#               vertices {
#                 x: 156
#                 y: 76
#               }
#               vertices {
#                 x: 131
#                 y: 76
#               }
#             }
#             text: "이"
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 162
#                 y: 43
#               }
#               vertices {
#                 x: 187
#                 y: 43
#               }
#               vertices {
#                 x: 187
#                 y: 76
#               }
#               vertices {
#                 x: 162
#                 y: 76
#               }
#             }
#             text: "거"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "ko"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 203
#               y: 43
#             }
#             vertices {
#               x: 294
#               y: 43
#             }
#             vertices {
#               x: 294
#               y: 76
#             }
#             vertices {
#               x: 203
#               y: 76
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 203
#                 y: 43
#               }
#               vertices {
#                 x: 232
#                 y: 43
#               }
#               vertices {
#                 x: 232
#                 y: 76
#               }
#               vertices {
#                 x: 203
#                 y: 76
#               }
#             }
#             text: "가"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 234
#                 y: 43
#               }
#               vertices {
#                 x: 259
#                 y: 43
#               }
#               vertices {
#                 x: 259
#                 y: 76
#               }
#               vertices {
#                 x: 234
#                 y: 76
#               }
#             }
#             text: "지"
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 264
#                 y: 43
#               }
#               vertices {
#                 x: 294
#                 y: 43
#               }
#               vertices {
#                 x: 294
#                 y: 76
#               }
#               vertices {
#                 x: 264
#                 y: 76
#               }
#             }
#             text: "고"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "ko"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 305
#               y: 43
#             }
#             vertices {
#               x: 366
#               y: 43
#             }
#             vertices {
#               x: 366
#               y: 76
#             }
#             vertices {
#               x: 305
#               y: 76
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 305
#                 y: 43
#               }
#               vertices {
#                 x: 335
#                 y: 43
#               }
#               vertices {
#                 x: 335
#                 y: 76
#               }
#               vertices {
#                 x: 305
#                 y: 76
#               }
#             }
#             text: "노"
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 336
#                 y: 43
#               }
#               vertices {
#                 x: 366
#                 y: 43
#               }
#               vertices {
#                 x: 366
#                 y: 76
#               }
#               vertices {
#                 x: 336
#                 y: 76
#               }
#             }
#             text: "는"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "ko"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 377
#               y: 43
#             }
#             vertices {
#               x: 438
#               y: 43
#             }
#             vertices {
#               x: 438
#               y: 76
#             }
#             vertices {
#               x: 377
#               y: 76
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 377
#                 y: 43
#               }
#               vertices {
#                 x: 405
#                 y: 43
#               }
#               vertices {
#                 x: 405
#                 y: 76
#               }
#               vertices {
#                 x: 377
#                 y: 76
#               }
#             }
#             text: "것"
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: LINE_BREAK
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 409
#                 y: 43
#               }
#               vertices {
#                 x: 438
#                 y: 43
#               }
#               vertices {
#                 x: 438
#                 y: 76
#               }
#               vertices {
#                 x: 409
#                 y: 76
#               }
#             }
#             text: "도"
#           }
#         }
#       }
#       block_type: TEXT
#     }
#     blocks {
#       bounding_box {
#         vertices {
#           x: 151
#           y: 85
#         }
#         vertices {
#           x: 342
#           y: 85
#         }
#         vertices {
#           x: 342
#           y: 117
#         }
#         vertices {
#           x: 151
#           y: 117
#         }
#       }
#       paragraphs {
#         bounding_box {
#           vertices {
#             x: 151
#             y: 85
#           }
#           vertices {
#             x: 342
#             y: 85
#           }
#           vertices {
#             x: 342
#             y: 117
#           }
#           vertices {
#             x: 151
#             y: 117
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "ko"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 151
#               y: 85
#             }
#             vertices {
#               x: 211
#               y: 85
#             }
#             vertices {
#               x: 211
#               y: 117
#             }
#             vertices {
#               x: 151
#               y: 117
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 151
#                 y: 85
#               }
#               vertices {
#                 x: 178
#                 y: 85
#               }
#               vertices {
#                 x: 178
#                 y: 117
#               }
#               vertices {
#                 x: 151
#                 y: 117
#               }
#             }
#             text: "너"
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 180
#                 y: 85
#               }
#               vertices {
#                 x: 211
#                 y: 85
#               }
#               vertices {
#                 x: 211
#                 y: 117
#               }
#               vertices {
#                 x: 180
#                 y: 117
#               }
#             }
#             text: "무"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "ko"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 221
#               y: 85
#             }
#             vertices {
#               x: 315
#               y: 85
#             }
#             vertices {
#               x: 315
#               y: 117
#             }
#             vertices {
#               x: 221
#               y: 117
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 221
#                 y: 85
#               }
#               vertices {
#                 x: 249
#                 y: 85
#               }
#               vertices {
#                 x: 249
#                 y: 117
#               }
#               vertices {
#                 x: 221
#                 y: 117
#               }
#             }
#             text: "귀"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 254
#                 y: 85
#               }
#               vertices {
#                 x: 282
#                 y: 85
#               }
#               vertices {
#                 x: 282
#                 y: 117
#               }
#               vertices {
#                 x: 254
#                 y: 117
#               }
#             }
#             text: "여"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 283
#                 y: 85
#               }
#               vertices {
#                 x: 315
#                 y: 85
#               }
#               vertices {
#                 x: 315
#                 y: 117
#               }
#               vertices {
#                 x: 283
#                 y: 117
#               }
#             }
#             text: "웠"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "ko"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 315
#               y: 85
#             }
#             vertices {
#               x: 342
#               y: 85
#             }
#             vertices {
#               x: 342
#               y: 117
#             }
#             vertices {
#               x: 315
#               y: 117
#             }
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: LINE_BREAK
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 315
#                 y: 85
#               }
#               vertices {
#                 x: 342
#                 y: 85
#               }
#               vertices {
#                 x: 342
#                 y: 117
#               }
#               vertices {
#                 x: 315
#                 y: 117
#               }
#             }
#             text: "지"
#           }
#         }
#       }
#       block_type: TEXT
#     }
#     blocks {
#       bounding_box {
#         vertices {
#           x: 266
#           y: 651
#         }
#         vertices {
#           x: 644
#           y: 651
#         }
#         vertices {
#           x: 644
#           y: 683
#         }
#         vertices {
#           x: 266
#           y: 683
#         }
#       }
#       paragraphs {
#         bounding_box {
#           vertices {
#             x: 266
#             y: 651
#           }
#           vertices {
#             x: 644
#             y: 651
#           }
#           vertices {
#             x: 644
#             y: 683
#           }
#           vertices {
#             x: 266
#             y: 683
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "ko"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 266
#               y: 651
#             }
#             vertices {
#               x: 356
#               y: 651
#             }
#             vertices {
#               x: 356
#               y: 683
#             }
#             vertices {
#               x: 266
#               y: 683
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 266
#                 y: 651
#               }
#               vertices {
#                 x: 296
#                 y: 651
#               }
#               vertices {
#                 x: 296
#                 y: 683
#               }
#               vertices {
#                 x: 266
#                 y: 683
#               }
#             }
#             text: "그"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 299
#                 y: 651
#               }
#               vertices {
#                 x: 324
#                 y: 651
#               }
#               vertices {
#                 x: 324
#                 y: 683
#               }
#               vertices {
#                 x: 299
#                 y: 683
#               }
#             }
#             text: "러"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 330
#                 y: 651
#               }
#               vertices {
#                 x: 356
#                 y: 651
#               }
#               vertices {
#                 x: 356
#                 y: 683
#               }
#               vertices {
#                 x: 330
#                 y: 683
#               }
#             }
#             text: "게"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "ko"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 362
#               y: 651
#             }
#             vertices {
#               x: 378
#               y: 651
#             }
#             vertices {
#               x: 378
#               y: 683
#             }
#             vertices {
#               x: 362
#               y: 683
#             }
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 362
#                 y: 651
#               }
#               vertices {
#                 x: 378
#                 y: 651
#               }
#               vertices {
#                 x: 378
#                 y: 683
#               }
#               vertices {
#                 x: 362
#                 y: 683
#               }
#             }
#             text: "~"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "ko"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 393
#               y: 651
#             }
#             vertices {
#               x: 449
#               y: 651
#             }
#             vertices {
#               x: 449
#               y: 683
#             }
#             vertices {
#               x: 393
#               y: 683
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 393
#                 y: 651
#               }
#               vertices {
#                 x: 417
#                 y: 651
#               }
#               vertices {
#                 x: 417
#                 y: 683
#               }
#               vertices {
#                 x: 393
#                 y: 683
#               }
#             }
#             text: "언"
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 423
#                 y: 651
#               }
#               vertices {
#                 x: 449
#                 y: 651
#               }
#               vertices {
#                 x: 449
#                 y: 683
#               }
#               vertices {
#                 x: 423
#                 y: 683
#               }
#             }
#             text: "제"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "ko"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 465
#               y: 651
#             }
#             vertices {
#               x: 553
#               y: 651
#             }
#             vertices {
#               x: 553
#               y: 683
#             }
#             vertices {
#               x: 465
#               y: 683
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 465
#                 y: 651
#               }
#               vertices {
#                 x: 489
#                 y: 651
#               }
#               vertices {
#                 x: 489
#                 y: 683
#               }
#               vertices {
#                 x: 465
#                 y: 683
#               }
#             }
#             text: "이"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 495
#                 y: 651
#               }
#               vertices {
#                 x: 521
#                 y: 651
#               }
#               vertices {
#                 x: 521
#                 y: 683
#               }
#               vertices {
#                 x: 495
#                 y: 683
#               }
#             }
#             text: "렇"
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 527
#                 y: 651
#               }
#               vertices {
#                 x: 553
#                 y: 651
#               }
#               vertices {
#                 x: 553
#                 y: 683
#               }
#               vertices {
#                 x: 527
#                 y: 683
#               }
#             }
#             text: "게"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "ko"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 570
#               y: 651
#             }
#             vertices {
#               x: 625
#               y: 651
#             }
#             vertices {
#               x: 625
#               y: 683
#             }
#             vertices {
#               x: 570
#               y: 683
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 570
#                 y: 651
#               }
#               vertices {
#                 x: 597
#                 y: 651
#               }
#               vertices {
#                 x: 597
#                 y: 683
#               }
#               vertices {
#                 x: 570
#                 y: 683
#               }
#             }
#             text: "컸"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 598
#                 y: 651
#               }
#               vertices {
#                 x: 625
#                 y: 651
#               }
#               vertices {
#                 x: 625
#                 y: 683
#               }
#               vertices {
#                 x: 598
#                 y: 683
#               }
#             }
#             text: "지"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "ko"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 630
#               y: 651
#             }
#             vertices {
#               x: 644
#               y: 651
#             }
#             vertices {
#               x: 644
#               y: 683
#             }
#             vertices {
#               x: 630
#               y: 683
#             }
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: LINE_BREAK
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 630
#                 y: 651
#               }
#               vertices {
#                 x: 644
#                 y: 651
#               }
#               vertices {
#                 x: 644
#                 y: 683
#               }
#               vertices {
#                 x: 630
#                 y: 683
#               }
#             }
#             text: "?"
#           }
#         }
#       }
#       block_type: TEXT
#     }
#     blocks {
#       bounding_box {
#         vertices {
#           x: 598
#           y: 683
#         }
#         vertices {
#           x: 661
#           y: 681
#         }
#         vertices {
#           x: 662
#           y: 700
#         }
#         vertices {
#           x: 599
#           y: 702
#         }
#       }
#       paragraphs {
#         bounding_box {
#           vertices {
#             x: 598
#             y: 683
#           }
#           vertices {
#             x: 661
#             y: 681
#           }
#           vertices {
#             x: 662
#             y: 700
#           }
#           vertices {
#             x: 599
#             y: 702
#           }
#         }
#         words {
#           bounding_box {
#             vertices {
#               x: 598
#               y: 683
#             }
#             vertices {
#               x: 661
#               y: 681
#             }
#             vertices {
#               x: 662
#               y: 700
#             }
#             vertices {
#               x: 599
#               y: 702
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 598
#                 y: 684
#               }
#               vertices {
#                 x: 614
#                 y: 683
#               }
#               vertices {
#                 x: 615
#                 y: 701
#               }
#               vertices {
#                 x: 599
#                 y: 702
#               }
#             }
#             text: "T"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 612
#                 y: 683
#               }
#               vertices {
#                 x: 631
#                 y: 682
#               }
#               vertices {
#                 x: 632
#                 y: 700
#               }
#               vertices {
#                 x: 613
#                 y: 701
#               }
#             }
#             text: "O"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 629
#                 y: 682
#               }
#               vertices {
#                 x: 650
#                 y: 681
#               }
#               vertices {
#                 x: 651
#                 y: 699
#               }
#               vertices {
#                 x: 630
#                 y: 700
#               }
#             }
#             text: "O"
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: LINE_BREAK
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 640
#                 y: 682
#               }
#               vertices {
#                 x: 661
#                 y: 681
#               }
#               vertices {
#                 x: 662
#                 y: 699
#               }
#               vertices {
#                 x: 641
#                 y: 700
#               }
#             }
#             text: "K"
#           }
#         }
#       }
#       block_type: TEXT
#     }
#   }
#   text: "\"어제 이거 가지고 노는 것도\n너무 귀여웠지\n그러게~ 언제 이렇게 컸지?\nTOOK"
# }

# %%
annotations = response.text_annotations

annotations
# Out:
# [locale: "ko"
# description: "\"어제 이거 가지고 노는 것도\n너무 귀여웠지\n그러게~ 언제 이렇게 컸지?\nTOOK"
# bounding_poly {
#   vertices {
#     x: 49
#     y: 43
#   }
#   vertices {
#     x: 662
#     y: 43
#   }
#   vertices {
#     x: 662
#     y: 702
#   }
#   vertices {
#     x: 49
#     y: 702
#   }
# }
# , description: "\""
# bounding_poly {
#   vertices {
#     x: 49
#     y: 43
#   }
#   vertices {
#     x: 65
#     y: 43
#   }
#   vertices {
#     x: 65
#     y: 76
#   }
#   vertices {
#     x: 49
#     y: 76
#   }
# }
# , description: "어제"
# bounding_poly {
#   vertices {
#     x: 58
#     y: 43
#   }
#   vertices {
#     x: 116
#     y: 43
#   }
#   vertices {
#     x: 116
#     y: 76
#   }
#   vertices {
#     x: 58
#     y: 76
#   }
# }
# , description: "이거"
# bounding_poly {
#   vertices {
#     x: 131
#     y: 43
#   }
#   vertices {
#     x: 187
#     y: 43
#   }
#   vertices {
#     x: 187
#     y: 76
#   }
#   vertices {
#     x: 131
#     y: 76
#   }
# }
# , description: "가지고"
# bounding_poly {
#   vertices {
#     x: 203
#     y: 43
#   }
#   vertices {
#     x: 294
#     y: 43
#   }
#   vertices {
#     x: 294
#     y: 76
#   }
#   vertices {
#     x: 203
#     y: 76
#   }
# }
# , description: "노는"
# bounding_poly {
#   vertices {
#     x: 305
#     y: 43
#   }
#   vertices {
#     x: 366
#     y: 43
#   }
#   vertices {
#     x: 366
#     y: 76
#   }
#   vertices {
#     x: 305
#     y: 76
#   }
# }
# , description: "것도"
# bounding_poly {
#   vertices {
#     x: 377
#     y: 43
#   }
#   vertices {
#     x: 438
#     y: 43
#   }
#   vertices {
#     x: 438
#     y: 76
#   }
#   vertices {
#     x: 377
#     y: 76
#   }
# }
# , description: "너무"
# bounding_poly {
#   vertices {
#     x: 151
#     y: 85
#   }
#   vertices {
#     x: 211
#     y: 85
#   }
#   vertices {
#     x: 211
#     y: 117
#   }
#   vertices {
#     x: 151
#     y: 117
#   }
# }
# , description: "귀여웠"
# bounding_poly {
#   vertices {
#     x: 221
#     y: 85
#   }
#   vertices {
#     x: 315
#     y: 85
#   }
#   vertices {
#     x: 315
#     y: 117
#   }
#   vertices {
#     x: 221
#     y: 117
#   }
# }
# , description: "지"
# bounding_poly {
#   vertices {
#     x: 315
#     y: 85
#   }
#   vertices {
#     x: 342
#     y: 85
#   }
#   vertices {
#     x: 342
#     y: 117
#   }
#   vertices {
#     x: 315
#     y: 117
#   }
# }
# , description: "그러게"
# bounding_poly {
#   vertices {
#     x: 266
#     y: 651
#   }
#   vertices {
#     x: 356
#     y: 651
#   }
#   vertices {
#     x: 356
#     y: 683
#   }
#   vertices {
#     x: 266
#     y: 683
#   }
# }
# , description: "~"
# bounding_poly {
#   vertices {
#     x: 362
#     y: 651
#   }
#   vertices {
#     x: 378
#     y: 651
#   }
#   vertices {
#     x: 378
#     y: 683
#   }
#   vertices {
#     x: 362
#     y: 683
#   }
# }
# , description: "언제"
# bounding_poly {
#   vertices {
#     x: 393
#     y: 651
#   }
#   vertices {
#     x: 449
#     y: 651
#   }
#   vertices {
#     x: 449
#     y: 683
#   }
#   vertices {
#     x: 393
#     y: 683
#   }
# }
# , description: "이렇게"
# bounding_poly {
#   vertices {
#     x: 465
#     y: 651
#   }
#   vertices {
#     x: 553
#     y: 651
#   }
#   vertices {
#     x: 553
#     y: 683
#   }
#   vertices {
#     x: 465
#     y: 683
#   }
# }
# , description: "컸지"
# bounding_poly {
#   vertices {
#     x: 570
#     y: 651
#   }
#   vertices {
#     x: 625
#     y: 651
#   }
#   vertices {
#     x: 625
#     y: 683
#   }
#   vertices {
#     x: 570
#     y: 683
#   }
# }
# , description: "?"
# bounding_poly {
#   vertices {
#     x: 630
#     y: 651
#   }
#   vertices {
#     x: 644
#     y: 651
#   }
#   vertices {
#     x: 644
#     y: 683
#   }
#   vertices {
#     x: 630
#     y: 683
#   }
# }
# , description: "TOOK"
# bounding_poly {
#   vertices {
#     x: 598
#     y: 683
#   }
#   vertices {
#     x: 661
#     y: 681
#   }
#   vertices {
#     x: 662
#     y: 700
#   }
#   vertices {
#     x: 599
#     y: 702
#   }
# }
# ]

# %%
annotations[0]
# Out:
# locale: "ko"
# description: "\"어제 이거 가지고 노는 것도\n너무 귀여웠지\n그러게~ 언제 이렇게 컸지?\nTOOK"
# bounding_poly {
#   vertices {
#     x: 49
#     y: 43
#   }
#   vertices {
#     x: 662
#     y: 43
#   }
#   vertices {
#     x: 662
#     y: 702
#   }
#   vertices {
#     x: 49
#     y: 702
#   }
# }

# %%
annotations[1:]
# Out:
# [description: "\""
#  bounding_poly {
#    vertices {
#      x: 49
#      y: 43
#    }
#    vertices {
#      x: 65
#      y: 43
#    }
#    vertices {
#      x: 65
#      y: 76
#    }
#    vertices {
#      x: 49
#      y: 76
#    }
#  },
#  description: "어제"
#  bounding_poly {
#    vertices {
#      x: 58
#      y: 43
#    }
#    vertices {
#      x: 116
#      y: 43
#    }
#    vertices {
#      x: 116
#      y: 76
#    }
#    vertices {
#      x: 58
#      y: 76
#    }
#  },
#  description: "이거"
#  bounding_poly {
#    vertices {
#      x: 131
#      y: 43
#    }
#    vertices {
#      x: 187
#      y: 43
#    }
#    vertices {
#      x: 187
#      y: 76
#    }
#    vertices {
#      x: 131
#      y: 76
#    }
#  },
#  description: "가지고"
#  bounding_poly {
#    vertices {
#      x: 203
#      y: 43
#    }
#    vertices {
#      x: 294
#      y: 43
#    }
#    vertices {
#      x: 294
#      y: 76
#    }
#    vertices {
#      x: 203
#      y: 76
#    }
#  },
#  description: "노는"
#  bounding_poly {
#    vertices {
#      x: 305
#      y: 43
#    }
#    vertices {
#      x: 366
#      y: 43
#    }
#    vertices {
#      x: 366
#      y: 76
#    }
#    vertices {
#      x: 305
#      y: 76
#    }
#  },
#  description: "것도"
#  bounding_poly {
#    vertices {
#      x: 377
#      y: 43
#    }
#    vertices {
#      x: 438
#      y: 43
#    }
#    vertices {
#      x: 438
#      y: 76
#    }
#    vertices {
#      x: 377
#      y: 76
#    }
#  },
#  description: "너무"
#  bounding_poly {
#    vertices {
#      x: 151
#      y: 85
#    }
#    vertices {
#      x: 211
#      y: 85
#    }
#    vertices {
#      x: 211
#      y: 117
#    }
#    vertices {
#      x: 151
#      y: 117
#    }
#  },
#  description: "귀여웠"
#  bounding_poly {
#    vertices {
#      x: 221
#      y: 85
#    }
#    vertices {
#      x: 315
#      y: 85
#    }
#    vertices {
#      x: 315
#      y: 117
#    }
#    vertices {
#      x: 221
#      y: 117
#    }
#  },
#  description: "지"
#  bounding_poly {
#    vertices {
#      x: 315
#      y: 85
#    }
#    vertices {
#      x: 342
#      y: 85
#    }
#    vertices {
#      x: 342
#      y: 117
#    }
#    vertices {
#      x: 315
#      y: 117
#    }
#  },
#  description: "그러게"
#  bounding_poly {
#    vertices {
#      x: 266
#      y: 651
#    }
#    vertices {
#      x: 356
#      y: 651
#    }
#    vertices {
#      x: 356
#      y: 683
#    }
#    vertices {
#      x: 266
#      y: 683
#    }
#  },
#  description: "~"
#  bounding_poly {
#    vertices {
#      x: 362
#      y: 651
#    }
#    vertices {
#      x: 378
#      y: 651
#    }
#    vertices {
#      x: 378
#      y: 683
#    }
#    vertices {
#      x: 362
#      y: 683
#    }
#  },
#  description: "언제"
#  bounding_poly {
#    vertices {
#      x: 393
#      y: 651
#    }
#    vertices {
#      x: 449
#      y: 651
#    }
#    vertices {
#      x: 449
#      y: 683
#    }
#    vertices {
#      x: 393
#      y: 683
#    }
#  },
#  description: "이렇게"
#  bounding_poly {
#    vertices {
#      x: 465
#      y: 651
#    }
#    vertices {
#      x: 553
#      y: 651
#    }
#    vertices {
#      x: 553
#      y: 683
#    }
#    vertices {
#      x: 465
#      y: 683
#    }
#  },
#  description: "컸지"
#  bounding_poly {
#    vertices {
#      x: 570
#      y: 651
#    }
#    vertices {
#      x: 625
#      y: 651
#    }
#    vertices {
#      x: 625
#      y: 683
#    }
#    vertices {
#      x: 570
#      y: 683
#    }
#  },
#  description: "?"
#  bounding_poly {
#    vertices {
#      x: 630
#      y: 651
#    }
#    vertices {
#      x: 644
#      y: 651
#    }
#    vertices {
#      x: 644
#      y: 683
#    }
#    vertices {
#      x: 630
#      y: 683
#    }
#  },
#  description: "TOOK"
#  bounding_poly {
#    vertices {
#      x: 598
#      y: 683
#    }
#    vertices {
#      x: 661
#      y: 681
#    }
#    vertices {
#      x: 662
#      y: 700
#    }
#    vertices {
#      x: 599
#      y: 702
#    }
#  }]

# %% [markdown]
# ## 이미지에 박스 그리기

# %%
from PIL import ImageDraw 

image_boxes = image.copy()
draw = ImageDraw.Draw(image_boxes)

for annot in annotations[1:]:
    v = annot.bounding_poly.vertices
    print(v)
    print("=====")
    print(v[0].x, v[0].y, "|", v[1].x, v[1].y, "|", v[2].x, v[2].y, "|", v[3].x, v[3].y)
    print("="*100)

    x1 = v[0].x
    y1 = v[0].y
    x2 = v[2].x
    y2 = v[2].y

    draw.rectangle([x1, y1, x2, y2], outline="red", width=2)
# Out:
# [x: 49
# y: 43
# , x: 65
# y: 43
# , x: 65
# y: 76
# , x: 49
# y: 76
# ]
# =====
# 49 43 | 65 43 | 65 76 | 49 76
# ====================================================================================================
# [x: 58
# y: 43
# , x: 116
# y: 43
# , x: 116
# y: 76
# , x: 58
# y: 76
# ]
# =====
# 58 43 | 116 43 | 116 76 | 58 76
# ====================================================================================================
# [x: 131
# y: 43
# , x: 187
# y: 43
# , x: 187
# y: 76
# , x: 131
# y: 76
# ]
# =====
# 131 43 | 187 43 | 187 76 | 131 76
# ====================================================================================================
# [x: 203
# y: 43
# , x: 294
# y: 43
# , x: 294
# y: 76
# , x: 203
# y: 76
# ]
# =====
# 203 43 | 294 43 | 294 76 | 203 76
# ====================================================================================================
# [x: 305
# y: 43
# , x: 366
# y: 43
# , x: 366
# y: 76
# , x: 305
# y: 76
# ]
# =====
# 305 43 | 366 43 | 366 76 | 305 76
# ====================================================================================================
# [x: 377
# y: 43
# , x: 438
# y: 43
# , x: 438
# y: 76
# , x: 377
# y: 76
# ]
# =====
# 377 43 | 438 43 | 438 76 | 377 76
# ====================================================================================================
# [x: 151
# y: 85
# , x: 211
# y: 85
# , x: 211
# y: 117
# , x: 151
# y: 117
# ]
# =====
# 151 85 | 211 85 | 211 117 | 151 117
# ====================================================================================================
# [x: 221
# y: 85
# , x: 315
# y: 85
# , x: 315
# y: 117
# , x: 221
# y: 117
# ]
# =====
# 221 85 | 315 85 | 315 117 | 221 117
# ====================================================================================================
# [x: 315
# y: 85
# , x: 342
# y: 85
# , x: 342
# y: 117
# , x: 315
# y: 117
# ]
# =====
# 315 85 | 342 85 | 342 117 | 315 117
# ====================================================================================================
# [x: 266
# y: 651
# , x: 356
# y: 651
# , x: 356
# y: 683
# , x: 266
# y: 683
# ]
# =====
# 266 651 | 356 651 | 356 683 | 266 683
# ====================================================================================================
# [x: 362
# y: 651
# , x: 378
# y: 651
# , x: 378
# y: 683
# , x: 362
# y: 683
# ]
# =====
# 362 651 | 378 651 | 378 683 | 362 683
# ====================================================================================================
# [x: 393
# y: 651
# , x: 449
# y: 651
# , x: 449
# y: 683
# , x: 393
# y: 683
# ]
# =====
# 393 651 | 449 651 | 449 683 | 393 683
# ====================================================================================================
# [x: 465
# y: 651
# , x: 553
# y: 651
# , x: 553
# y: 683
# , x: 465
# y: 683
# ]
# =====
# 465 651 | 553 651 | 553 683 | 465 683
# ====================================================================================================
# [x: 570
# y: 651
# , x: 625
# y: 651
# , x: 625
# y: 683
# , x: 570
# y: 683
# ]
# =====
# 570 651 | 625 651 | 625 683 | 570 683
# ====================================================================================================
# [x: 630
# y: 651
# , x: 644
# y: 651
# , x: 644
# y: 683
# , x: 630
# y: 683
# ]
# =====
# 630 651 | 644 651 | 644 683 | 630 683
# ====================================================================================================
# [x: 598
# y: 683
# , x: 661
# y: 681
# , x: 662
# y: 700
# , x: 599
# y: 702
# ]
# =====
# 598 683 | 661 681 | 662 700 | 599 702
# ====================================================================================================

# %%
plt.imshow(image_boxes)
plt.axis("off")
plt.show()

# %%
# 라이브러리 설치 uv add translate

# %%
from translate import Translator 

translator = Translator(from_lang="ko", to_lang="en")

# \n 으로 나누면 말풍선 덩어리 단위로 분리됨
chunks = [line for line in annotations[0].description.strip().split("\n") if line.strip()]

print("=== 원문 → 번역 ===")
translations = {}
for chunk in chunks:
    translated = translator.translate(chunk)
    translations[chunk] = translated
    print(f"{chunk}  →  {translated}")
# Out:
# === 원문 → 번역 ===
# "어제 이거 가지고 노는 것도  →  "Playing with this yesterday
# 너무 귀여웠지  →  It was so cute
# 그러게~ 언제 이렇게 컸지?  →  Yeah ~ When did she grow up like this?
# TOOK  →  Toook

# %%
# ── 1. annot_dict: 단어 → [x1, y1, x2, y2] ──────────────────────────
annot_dict = {}
for ann in annotations[1:]:
    v = ann.bounding_poly.vertices
    annot_dict[ann.description] = [v[0].x, v[0].y, v[2].x, v[2].y]

annot_dict
# Out:
# {'"': [49, 43, 65, 76],
#  '어제': [58, 43, 116, 76],
#  '이거': [131, 43, 187, 76],
#  '가지고': [203, 43, 294, 76],
#  '노는': [305, 43, 366, 76],
#  '것도': [377, 43, 438, 76],
#  '너무': [151, 85, 211, 117],
#  '귀여웠': [221, 85, 315, 117],
#  '지': [315, 85, 342, 117],
#  '그러게': [266, 651, 356, 683],
#  '~': [362, 651, 378, 683],
#  '언제': [393, 651, 449, 683],
#  '이렇게': [465, 651, 553, 683],
#  '컸지': [570, 651, 625, 683],
#  '?': [630, 651, 644, 683],
#  'TOOK': [598, 683, 662, 700]}

# %%
# ── 3. chunk_data: y좌표 기준으로 덩어리 bbox 계산 ───────────────────
import re 

Y_TOL = 20

chunk_data = []

for chunk in chunks:
    clean = re.sub(r'[^가-힣a-zA-Z0-9\s]', '', chunk).strip()
    words = clean.split()

    # 청크 단어와 매칭되는 annotation에서 anchor_y 잡기
    anchor_y = None
    for word in words:
        for key, coords in annot_dict.items():
            clean_key = re.sub(r'[^가-힣a-zA-Z0-9]', '', key)
            if clean_key and (word == clean_key or clean_key in word):
                anchor_y = (coords[1] + coords[3]) // 2
                break
        if anchor_y:
            break

    if anchor_y is None:
        continue

    # anchor_y 근처 같은 줄 annotation 모두 묶어 union bbox
    same_line = [c for c in annot_dict.values()
                 if abs((c[1] + c[3]) // 2 - anchor_y) <= Y_TOL]

    chunk_data.append({
        "text":      chunk,
        "translate": translations.get(chunk, ""),
        "box":       [min(c[0] for c in same_line),
                      min(c[1] for c in same_line),
                      max(c[2] for c in same_line),
                      max(c[3] for c in same_line)]
    })

chunk_data
# Out:
# [{'text': '"어제 이거 가지고 노는 것도',
#   'translate': '"Playing with this yesterday',
#   'box': [49, 43, 438, 76]},
#  {'text': '너무 귀여웠지',
#   'translate': 'It was so cute',
#   'box': [151, 85, 342, 117]},
#  {'text': '그러게~ 언제 이렇게 컸지?',
#   'translate': 'Yeah ~ When did she grow up like this?',
#   'box': [266, 651, 644, 683]},
#  {'text': 'TOOK', 'translate': 'Toook', 'box': [598, 683, 662, 700]}]

# %%
# ── 4. 이미지에 합성 ─────────────────────────────────────────────────
from PIL import ImageFont

FONT_PATH = "C:/Windows/Fonts/Arial.ttf"
FONT_SIZE = 25
font = ImageFont.truetype(FONT_PATH, FONT_SIZE)

image_translated = image.copy()
draw = ImageDraw.Draw(image_translated)

for item in chunk_data:
    x1, y1, x2, y2 = item["box"]
    draw.rectangle([x1, y1, x2, y2], fill="white", outline="red")
    draw.text((x1 + 2, y1 + 2), item["translate"], font=font, fill="black")

fig, axes = plt.subplots(1, 2, figsize=(10, 6))
axes[0].imshow(image)
axes[0].set_title("Original")
axes[0].axis("off")
axes[1].imshow(image_translated)
axes[1].set_title("Translate")
axes[1].axis("off")

plt.tight_layout()
plt.show()
